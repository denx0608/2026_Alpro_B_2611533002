# %% [markdown]
# <div align="center">
#
# **LAPORAN PRAKTIKUM**
#
# **ALGORITMA & PEMOGRAMAN**
#
# **“TIPE DATA DAN VARIABEL”**
#
# **Disusun Oleh :**
#
# **NABILA TASMAYENI**
#
# **2611533014**
#
# **Dosen Pengampu:**
#
# **Wahyudi.DR.. S.T.M.T**
#
# **Asisten Praktikum:**
#
# **SHERLY SUKMADIRA**
#
# <br>
#
#  ![images.png](attachment:images.png)
#
# <br>
#
# **FAKULTAS TEKNOLOGI INFORMASI**
#
# **DEPARTEMEN INFORMATIKA**
#
# **UNIVERSITAS ANDALAS**
#
# **2026**
#
# </div>

# %% [markdown]
# ## KATA PENGANTAR
# Puji dan syukur saya panjatkan kepada Tuhan Yang Maha Esa, karena atas rahmat dan kemudahan-Nya, laporan praktikum ini bisa selesai tepat pada waktunya.Laporan ini disusun untuk merangkum hasil praktikum mengenai dasar yang paling krusial dalam dunia pemrograman, yaitu tipe data dan variabel. Lewat praktikum kali ini, saya belajar bagaimana sebuah program menyimpan dan mengolah informasi. Di dalam laporan ini, fokus pembahasan akan mengupas tuntas penggunaan data teks (string), data angka (numerik), penentuan nilai tetap (konstanta), hingga logika benar-salah (boolean). Tidak ketinggalan, dibahas juga bagaimana cara program berinteraksi dengan pengguna melalui fitur input. Saya ingin mengucapkan terima kasih yang sebesar-besarnya kepada dosen pengampu serta para asisten laboratorium yang sudah sabar membimbing dan membagikan ilmunya selama sesi praktikum berlangsung.Tentu saja, laporan ini masih jauh dari kata sempurna. Oleh karena itu, kritik dan saran yang membangun sangat saya harapkan demi perbaikan di masa mendatang. Semoga laporan praktikum ini bisa memberikan manfaat dan menambah sedikit insight buat kita yang sedang sama-sama belajar coding.
#
# <div align ="right">
# Padang,2026
# <br><br><br>
# Nabila Tasmayeni
# <br>
# 2611533014
# </div>

# %% [markdown]
# ---
# # BAB I
# # PENDAHULUAN
#
# ## 1.1 Latar Belakang
# Di era digital saat ini, komputer sudah menjadi alat yang sangat diandalkan untuk menyelesaikan berbagai pekerjaan manusia dengan cepat. Namun, komputer sebenarnya tidak bisa berpikir sendiri. Agar komputer bisa bekerja sesuai keinginan kita, kita perlu memberikan instruksi yang jelas lewat kode program.Hal dasar yang harus kita pahami saat belajar coding adalah bagaimana program mengelola dan menyimpan informasi. agar tidak terjadi kesalahan pada proses input data ketika program dijalankan maka setiap variabel harus disesuaikan dengan tipe datanya. Misalnya, saat mengetik teks seperti nama atau alamat, program akan menyimpannya sebagai tipe data string. Ketika berhitung menggunakan angka, tipe data numerik-lah yang bekerja. Adapun saat kita membutuhkan nilai yang sifatnya mutlak dan tidak boleh diubah-ubah, seperti nilai pi dalam matematika, yang dalam coding disebut sebagai konstanta. Selain itu, kita menggunakan boolean untuk membantu program mengambil keputusan secara benar atau salah. Kita juga memakai fitur input agar pengguna bisa mengetikkan datanya sendiri, sehingga program terasa lebih hidup dan interaktif.
# ## 1.2 Tujuan
# 1. Memahami pengertian dan penggunaan tipe data serta variabel dalam pemrograman.
# 2. Mengetahui penggunaan string untuk menyimpan data berupa teks dan numerik untuk menyimpan data berupa angka.
# 3. Memahami cara menggunakan input untuk menerima data dari pengguna.
# 4. Mengetahui fungsi konstanta sebagai nilai yang tetap dalam program.
# 5. Memahami penggunaan boolean untuk menyimpan nilai benar (true) atau salah (false).
#
# ## 1.3 Manfaat
# 1. Menambah pemahaman tentang tipe data dan variabel yang digunakan dalam pemrograman.
# 2. Membantu mengetahui cara penggunaan string dan numerik dalam menyimpan berbagai jenis data.
# 3. Melatih kemampuan menggunakan input untuk menerima data dari pengguna.
# 4. Memahami fungsi konstanta dalam menyimpan nilai yang tetap di dalam program.
# 5. Menambah pengalaman dalam menggunakan boolean untuk menentukan kondisi benar atau salah dalam sebuah program."

# %% [markdown]
# ---
# # BAB II
# # PEMBAHASAN
#
# ## 2.1 Dasar Teori
# Dalam pemrograman, tipe data dan variabel merupakan bagian dasar yang penting karena digunakan untuk menyimpan dan mengolah berbagai macam informasi. Tipe data menentukan jenis nilai yang dapat disimpan, sedangkan variabel digunakan sebagai tempat untuk menyimpan nilai tersebut. Dengan memahami tipe data dan variabel, kita bisa membuat program yang dapat menerima input, melakukan proses, dan menghasilkan output sesuai kebutuhan.
#
# 1) String
#
# String adalah tipe data yang digunakan untuk menyimpan teks atau kumpulan karakter. String biasanya ditulis menggunakan tanda kutip, misalnya \"Nabila\", \"Halo Dunia\", atau \"123\". Walaupun \"123\" terlihat seperti angka, jika ditulis sebagai string maka nilainya dianggap sebagai teks dan bukan angka yang bisa langsung digunakan untuk operasi matematika.
#
# 2) Numerik
#
# Tipe data numerik digunakan untuk menyimpan nilai berupa angka. Data numerik biasanya digunakan dalam perhitungan matematika, seperti penjumlahan, pengurangan, perkalian, dan pembagian. Contohnya adalah 10, 25, 3.14, dan 100. Data numerik dapat berupa bilangan bulat maupun bilangan desimal, tergantung kebutuhan program.
#
# 3) Input
#
# Input adalah data yang dimasukkan oleh pengguna ke dalam program. Input membuat program menjadi lebih interaktif karena nilai yang digunakan tidak selalu ditentukan dari awal oleh pembuat program. Contohnya, program dapat meminta pengguna memasukkan nama, umur, atau nilai ujian. Data yang diberikan melalui input kemudian dapat disimpan dalam variabel untuk diproses lebih lanjut.
#
# 4) Konstanta
#
# Konstanta adalah nilai yang tetap dan tidak berubah selama program berjalan. Konstanta biasanya digunakan untuk menyimpan nilai yang memang sudah ditentukan dan tidak perlu diubah, seperti nilai PI = 3.14 atau jumlah hari dalam satu minggu yaitu 7. Penggunaan konstanta dapat membuat program lebih mudah dipahami dan mengurangi kemungkinan terjadinya kesalahan saat program dijalankan.
#
# 5) Boolean
#
# Boolean adalah tipe data yang hanya memiliki dua kemungkinan nilai, yaitu True (benar) dan False (salah). Boolean sering digunakan dalam kondisi atau percabangan untuk menentukan apakah suatu pernyataan benar atau tidak. Contohnya, jika ingin mengecek apakah nilai seorang siswa lebih dari atau sama dengan 75, hasil pengecekannya dapat berupa True atau False.

# %% [markdown]
# ## 2.2 Kode Program
#
# ### 2.2.1 Program "String_2611533014"

# %%
#Buat file dengan nama string_2611533014.py
#nama variabel ditambah 4 digit nim terakhir contoh: nama_1234
#ganti programnya dan data masing2
nama_3014 ="nabila tasmayeni"
jenis_kelamin_3014 ='Perempuan'
alamat_3014 = """
    Jalan Anak Air
    Kec.koto tangah
    Kota Padang
"""
agama_3014 = 'Islam'
print("Nama saya adalah:", nama_3014)
print("Jenis kelamin saya adalah:",jenis_kelamin_3014)
print("Alamat saya adalah:",alamat_3014)
print("Agama saya adalah:", agama_3014)

# %% [markdown]
# **Penjelasan :**
# 1. Variabel nama_3014 digunakan untuk menyimpan nama. Angka 3014 ditambahkan pada nama variabel sesuai dengan ketentuan menggunakan 4 digit terakhir NIM.
# 2. Jenis_kelamin_3014 digunakan untuk menyimpan data jenis kelamin.
# 3. Variabel alamat_3014 digunakan untuk menyimpan alamat. Tiga tanda kutip (""") digunakan karena data alamat terdiri dari beberapa baris, sehingga teks dapat ditulis dalam bentuk multiline.
# 4. Variabel agama_3014 digunakan untuk menyimpan data agama.
# 5. Perintah print() digunakan untuk menampilkan tulisan dan nilai yang tersimpan di dalam variabel nama_3014, jenis_kelamin_3014, alamat_3014, dan agama_3014.

# %% [markdown]
# ### 2.2.2 Program "numerik_2611533014"

# %%
#Buat file dengan nama Numerik_2611533014.py
#nama variabel ditambah 4 digit terakhir NIM contoh:a_5500
#create a variable with integer value
a_3014 =  100
print("The type of variable having value",a_3014, "is", type(a_3014))

#create a variable with a float value
b_3014 =10.2345
print("The type of variable having value",b_3014,"is",type(b_3014))

#create a variable with complex value
c_3014 = 100+3j
print("The type of variable having value",c_3014,"is",type(c_3014))

# %% [markdown]
# **Penjelasan**
# 1. a_3014 = 100 -> integer, yaitu bilangan bulat.
# 2. b_3014 = 10.2345 -> float, yaitu bilangan desimal.
# 3. c_3014 = 100 + 3j -> complex, yaitu bilangan yang memiliki bagian real dan imajiner.
# 4. Fungsi type() digunakan untuk mengetahui tipe data dari setiap variabel.
# 5. Print() digunakan untuk menampilkan hasilnya ke layar.

# %% [markdown]
# ### 2.2.3 Program "Konstanta_2611533014"

# %%
#Buat file dengan nama Konstanta_2611533014.py
#Program ini menggunakan konstanta untuk menghitung luas lingkaran
#nama variabel ditambah 4 digit nim terakhir contoh:jari_3014

from typing import Final
PI : Final = 3.14
print("pi:%f % (PI)")
jari_3014 = float(input('masukkan nilai jari-jari:'))
luas_3014 = PI * jari_3014
print ("Luas lingkaran dengan jari %.2f adalah %2f" %(jari_3014,luas_3014))

# %% [markdown]
# **Penjelasan:**
# 1. PI : Final = 3.14 → membuat konstanta PI dengan nilai tetap 3,14.
# 2. input() → digunakan untuk meminta pengguna memasukkan nilai jari-jari lingkaran.
# 3. float() → mengubah input menjadi angka desimal.
# 4. luas_3014 = PI * jari_3014 → menghitung luas lingkaran berdasarkan nilai PI dan jari-jari.
# 5. print() → menampilkan nilai dan hasil luas lingkaran.
# 6. Fungsi Final digunakan untuk menandakan bahwa nilai PI merupakan konstanta yang seharusnya tidak diubah. Program ini menunjukkan penggunaan konstanta, input, variabel, dan operasi matematika dalam Python.

# %% [markdown]
# ### 2.2.4 Program "Input_2611533014"

# %%
#buat file dengan nama Input_2611533014.py
#Buat program untuk menghitung luas persegi panjang
#Nama variabel ditambah 4 digit nim terakhir contoh: panjang_1234
#Program ini menggunakan fungsi input()untuk meminta pengguna 
#memasukkan nilai panjang dan lebar persegi panjang.
#Nilai yang dimasukkan akan dikonversi menjadi tipe data integer
panjang_3014 = input ('Masukkan nilai panjang:')
lebar_3014 = input("Masukkan nilai lebar: ")
luas_3014 = int(panjang_3014)* int(lebar_3014)
print("luas =",luas_3014)

# %% [markdown]
# **Penjelasan:**
# 1. input() digunakan untuk meminta pengguna memasukkan nilai panjang dan lebar.
# 2. panjang_3014 dan lebar_3014 digunakan sebagai variabel untuk menyimpan nilai yang dimasukkan.
# 3. int() digunakan untuk mengubah data input menjadi bilangan integer, sehingga dapat digunakan dalam perhitungan.
# 4. luas_3014 = int(panjang_3014) * int(lebar_3014) digunakan untuk menghitung luas dengan mengalikan panjang dan lebar.
# 5. print() digunakan untuk menampilkan hasil luas persegi panjang ke layar.

# %% [markdown]
# ### 2.2.5 Program "Boolean_2611533014"

# %%
#Buat file dengan nama Boolean_2611533014.py
#Nama variabel ditambah 4 digit nim terakhir contoh:nilai_1234
#Deklarasi variabel dengan tipe data Boolean
is_lulus_3014 = True
is_cumlaude_3014 = True

# Menggunakan Boolean
nilai_3014 = 85
batas_lulus_3014 = 75

#Menentukan nilai boolean dari kondisi
status_kelulusan_3014 = nilai_3014 >= batas_lulus_3014 #hasilnya akan true

print("=== Check Kelulusan ===")
print("Nilai:",nilai_3014)
print("Apakah lulus?:",status_kelulusan_3014)
if is_lulus_3014 and is_cumlaude_3014:
        print("Selamat,Anda lulus dengan prediket Cum Laude")

# %% [markdown]
# **Penjelasan:**
# 1. is_lulus_3014 = True dan is_cumlaude_3014 = True → digunakan untuk menyimpan kondisi kelulusan dan predikat.
# 2. nilai_3014 = 85 dan batas_lulus_3014 = 75 → menyimpan nilai yang diperoleh dan nilai minimum untuk lulus.
# 3. status_kelulusan_3014 = nilai_3014 >= batas_lulus_3014 → membandingkan nilai dengan batas lulus. Karena 85 lebih besar dari 75, hasilnya adalah True.
# 4. print() → digunakan untuk menampilkan nilai dan status kelulusan.
# 5. if is_lulus_3014 and is_cumlaude_3014: → menggunakan operator and untuk mengecek apakah kedua kondisi bernilai True. Jika keduanya benar, program menampilkan ucapan bahwa pengguna lulus dengan predikat Cum Laude.

# %% [markdown]
# ---
# ## Tugas Praktikum
#
# **Soal :**
#
# ![Screenshot 2026-09-15 210358.png](<attachment:Screenshot 2026-09-15 210358.png>)

# %% [markdown]
# **Kode Jawaban :**
#
# a. Kode Program "Alpro_B_2611533014"

# %%
from typing import Final

BATAS_3014: Final[float] = 75.0

print("=== DATA PRAKTIKAN ===")

nama_3014 = input("Nama           : ")
nim_3014 = int(input("NIM            : "))
umur_3014 = int(input("Umur           : "))
jenis_3014 = input("Jenis Kelamin   : ")
semester_3014 = int(input("Semester       : "))
nilai_3014 = float(input("Nilai Praktikum: "))
alamat_3014 = input("Alamat         : ")

# Data complex
kode_3014 = complex(nim_3014, semester_3014)

# Cek kelulusan
lulus_3014 = nilai_3014 >= BATAS_3014

print("\n=== HASIL DATA ===")
print("Nama     :", nama_3014, "|", type(nama_3014))
print("NIM      :", nim_3014, "|", type(nim_3014))
print("Umur     :", umur_3014, "|", type(umur_3014))
print("Jenis Kelamin :", jenis_3014, "|", type(jenis_3014))
print("Semester :", semester_3014, "|", type(semester_3014))
print("Nilai    :", nilai_3014, "|", type(nilai_3014))
print("Alamat   :", alamat_3014, "|", type(alamat_3014))
print("Kode     :", kode_3014, "|", type(kode_3014))

print("\n=== STATUS KELULUSAN ===")
print("Batas Nilai :", BATAS_3014)
print("Lulus       :", lulus_3014, "|", type(lulus_3014))

if lulus_3014:
    print("Keterangan  : LULUS")
else:
    print("Keterangan  : TIDAK LULUS")
# Out:
# === DATA PRAKTIKAN ===
#
# === HASIL DATA ===
# Nama     : Nabila Tasmayeni | <class 'str'>
# NIM      : 2611533014 | <class 'int'>
# Umur     : 18 | <class 'int'>
# Jenis Kelamin : Perempuan | <class 'str'>
# Semester : 1 | <class 'int'>
# Nilai    : 80.0 | <class 'float'>
# Alamat   : Jl Anak Air | <class 'str'>
# Kode     : (2611533014+1j) | <class 'complex'>
#
# === STATUS KELULUSAN ===
# Batas Nilai : 75.0
# Lulus       : True | <class 'bool'>
# Keterangan  : LULUS

# %% [markdown]
# ---
# # BAB III
# # KESIMPULAN
#
# Berdasarkan praktikum yang telah dilakukan, dapat disimpulkan bahwa tipe data dan variabel merupakan bagian penting dalam pemrograman karena digunakan untuk menyimpan dan mengolah berbagai jenis data. String digunakan untuk menyimpan teks atau karakter, sedangkan numerik digunakan untuk menyimpan data berupa angka yang dapat digunakan dalam perhitungan.
#
# Selain itu, input digunakan agar program dapat menerima data dari pengguna sehingga program menjadi lebih interaktif. Konstanta digunakan untuk menyimpan nilai yang tetap dan tidak berubah selama program berjalan. Sementara itu, boolean digunakan untuk menunjukkan dua kondisi, yaitu benar (True) atau salah (False).
#
# Dengan memahami penggunaan string, numerik, input, konstanta, dan boolean, kita dapat membuat program yang lebih teratur dan sesuai dengan kebutuhan. Praktikum ini juga membantu memahami bagaimana data disimpan, dimasukkan, dan digunakan dalam sebuah program.

# %% [markdown]
# ---
# ## DAFTAR PUSTAKA
#
# [1] Python Software Foundation, \"Built-in Types,\" Python 3 Documentation, [2026]. [Online]. Tersedia: https://docs.python.org/3/library/stdtypes.html [Diakses 11 September 2026].
#
# [2] Python Software Foundation, \"An Informal Introduction to Python,\" Python 3 Documentation, [2026]. [Online]. Tersedia: https://docs.python.org/3/tutorial/introduction.html [Diakses 11 September 2026].
#
# [3] Robert Sedgewick dan Kevin Wayne, \"Built-in Types of Data,\" Introduction to Programming in Python, [Online]. Tersedia: https://introcs.cs.princeton.edu/python/12types/ [Diakses 11 September 2026].
#
# [4] Python Software Foundation, \"The Python Standard Library,\" Python Documentation, [2026]. [Online]. Tersedia: https://docs.python.org/3/library/ [Diakses 11 September 2026].
